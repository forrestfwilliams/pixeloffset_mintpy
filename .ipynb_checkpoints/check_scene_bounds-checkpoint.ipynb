# %%
# %matplotlib inline
import rasterio
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import glob
import os

matplotlib.rcParams['axes.formatter.useoffset'] = False

# %%
cd I:\sentinel2\upper
# Out:
# I:\sentinel2\upper

# %%
images = glob.glob('level2A\*\GRANULE\*\IMG_DATA\R10m\*B08_10m.jp2')
# images = [os.path.join(x,f'{os.path.basename(x)}_unw_phase.tif') for x in folders if 'zip' not in x]
len(images)
# Out:
# 26

# %%
df = pd.DataFrame(columns=['date','left','right','top','bottom'])

for i in images:
    with rasterio.open(i) as raster:
        bounds = raster.bounds
    dates = datetime.strptime(os.path.basename(i)[7:22],'%Y%m%dT%H%M%S')
#     date1, date2 = [datetime.strptime(x,'%Y%m%dT%H%M%S') for x in dates.split('_')]
    df = df.append({'date':dates,'left':bounds.left,'right':bounds.right,'top':bounds.top,'bottom':bounds.bottom},ignore_index=True)

df
# Out:
#                   date      left     right        top     bottom
# 0  2021-03-16 22:16:09  300000.0  409800.0  5700040.0  5590240.0
# 1  2021-01-25 22:16:09  300000.0  409800.0  5700040.0  5590240.0
# 2  2020-12-16 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 3  2020-07-09 22:16:09  300000.0  409800.0  5700040.0  5590240.0
# 4  2020-04-10 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 5  2020-03-11 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 6  2019-11-22 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 7  2019-11-02 22:16:09  300000.0  409800.0  5700040.0  5590240.0
# 8  2019-01-16 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 9  2018-10-18 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 10 2017-11-22 22:15:49  300000.0  409800.0  5700040.0  5590240.0
# 11 2017-08-04 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 12 2020-08-03 22:16:11  300000.0  409800.0  5700040.0  5590240.0
# 13 2019-03-02 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 14 2018-03-17 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 15 2017-05-21 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 16 2017-05-01 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 17 2017-04-21 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 18 2016-11-22 22:16:02  300000.0  409800.0  5700040.0  5590240.0
# 19 2018-07-05 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 20 2017-10-13 22:15:49  300000.0  409800.0  5700040.0  5590240.0
# 21 2021-02-19 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 22 2016-02-06 22:15:52  300000.0  409800.0  5700040.0  5590240.0
# 23 2020-02-10 22:15:59  300000.0  409800.0  5700040.0  5590240.0
# 24 2020-01-16 22:16:01  300000.0  409800.0  5700040.0  5590240.0
# 25 2020-03-31 22:15:59  300000.0  409800.0  5700040.0  5590240.0

# %%
# a larger limit will include more images
limit = 1e30

top = df['top'].max() - limit
bottom = df['bottom'].min() + limit
left = df['left'].min() + limit
right = df['right'].max() - limit

plot_df = df.loc[(df['left'] <= left) & (df['right'] >= right) & (df['top'] >= top) & (df['bottom'] <= bottom)]

# dropped_dates = set(df['date1']).union(set(df['date2'])) - set(plot_df['date1']).union(set(plot_df['date2']))
# dropped_ints = set(df['date12']) - set(plot_df['date12'])
# formatted_dates = [x.strftime('%Y%m%dT%H%M%S') for x in list(dropped_dates)]

# print('Coordinate ranges')
# print(plot_df[['left','right','top','bottom']].max() - plot_df[['left','right','top','bottom']].min())
# print('\n')

# print(f'Drops {len(dropped_dates)} dates and {len(dropped_ints)} interferograms:')
# print(formatted_dates)

fig, axs = plt.subplots(2,2,sharex=True,sharey=False,figsize=(10,10))
for ax,i in zip(axs.flatten(),['left','right','top','bottom']):
    ax.scatter(plot_df['date'],plot_df[i])
    ax.set_title(i.capitalize())
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=90)

plt.show()
