# %% [markdown]
# # MintPy Offset

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
# %matplotlib widget
from osgeo import gdal
import numpy as np
import glob
import os
import pandas as pd
import matplotlib.pyplot as plt
from mintpy.utils import readfile, writefile, utils as ut
from mintpy.objects import ifgramStack
from mintpy import workflow, view, tsview, plot_network, plot_transection, plot_coherence_matrix

# %% [markdown]
# ## Prep data

# %%
# rm -rf /home/fw/data/poroa_32

# %%
mkdir /home/fw/data/poroa_32

# %%
cd /home/fw/data/poroa_32
# Out:
# /home/fw/data/poroa_32

# %%
ls /mnt/i/sentinel2/upper/poroa_32
# Out:
# cosicorr_20160206T221552_20190302T221601.dat*
# cosicorr_20160206T221552_20190302T221601.hdr*
# cosicorr_20160206T221552_20190302T221601_EWOffset.tif*
# cosicorr_20160206T221552_20190302T221601_NSOffset.tif*
# cosicorr_20160206T221552_20190302T221601_offsetSNR.tif*
# cosicorr_20160206T221552_20200210T221559.dat*
# cosicorr_20160206T221552_20200210T221559.hdr*
# cosicorr_20160206T221552_20200210T221559_EWOffset.tif*
# cosicorr_20160206T221552_20200210T221559_NSOffset.tif*
# cosicorr_20160206T221552_20200210T221559_offsetSNR.tif*
# cosicorr_20160206T221552_20210125T221609.dat*
# cosicorr_20160206T221552_20210125T221609.hdr*
# cosicorr_20160206T221552_20210125T221609_EWOffset.tif*
# cosicorr_20160206T221552_20210125T221609_NSOffset.tif*
# cosicorr_20160206T221552_20210125T221609_offsetSNR.tif*
# cosicorr_20160206T221552_20210219T221601.dat*
# cosicorr_20160206T221552_20210219T221601.hdr*
# cosicorr_20160206T221552_20210219T221601_EWOffset.tif*
# cosicorr_20160206T221552_20210219T221601_NSOffset.tif*
# cosicorr_20160206T221552_20210219T221601_offsetSNR.tif*
# cosicorr_20161122T221602_20171122T221549.dat*
# cosicorr_20161122T221602_20171122T221549.hdr*
# cosicorr_20161122T221602_20171122T221549_EWOffset.tif*
# cosicorr_20161122T221602_20171122T221549_NSOffset.tif*
# cosicorr_20161122T221602_20171122T221549_offsetSNR.tif*
# cosicorr_20161122T221602_20191102T221609.dat*
# cosicorr_20161122T221602_20191102T221609.hdr*
# cosicorr_20161122T221602_20191102T221609_EWOffset.tif*
# cosicorr_20161122T221602_20191102T221609_NSOffset.tif*
# cosicorr_20161122T221602_20191102T221609_offsetSNR.tif*
# cosicorr_20161122T221602_20191122T221559.dat*
# cosicorr_20161122T221602_20191122T221559.hdr*
# cosicorr_20161122T221602_20191122T221559_EWOffset.tif*
# cosicorr_20161122T221602_20191122T221559_NSOffset.tif*
# cosicorr_20161122T221602_20191122T221559_offsetSNR.tif*
# cosicorr_20161122T221602_20201216T221559.dat*
# cosicorr_20161122T221602_20201216T221559.hdr*
# cosicorr_20161122T221602_20201216T221559_EWOffset.tif*
# cosicorr_20161122T221602_20201216T221559_NSOffset.tif*
# cosicorr_20161122T221602_20201216T221559_offsetSNR.tif*
# cosicorr_20170421T221601_20200331T221559.dat*
# cosicorr_20170421T221601_20200331T221559.hdr*
# cosicorr_20170421T221601_20200331T221559_EWOffset.tif*
# cosicorr_20170421T221601_20200331T221559_NSOffset.tif*
# cosicorr_20170421T221601_20200331T221559_offsetSNR.tif*
# cosicorr_20170421T221601_20200410T221559.dat*
# cosicorr_20170421T221601_20200410T221559.hdr*
# cosicorr_20170421T221601_20200410T221559_EWOffset.tif*
# cosicorr_20170421T221601_20200410T221559_NSOffset.tif*
# cosicorr_20170421T221601_20200410T221559_offsetSNR.tif*
# cosicorr_20170501T221601_20200331T221559.dat*
# cosicorr_20170501T221601_20200331T221559.hdr*
# cosicorr_20170501T221601_20200331T221559_EWOffset.tif*
# cosicorr_20170501T221601_20200331T221559_NSOffset.tif*
# cosicorr_20170501T221601_20200331T221559_offsetSNR.tif*
# cosicorr_20170501T221601_20200410T221559.dat*
# cosicorr_20170501T221601_20200410T221559.hdr*
# cosicorr_20170501T221601_20200410T221559_EWOffset.tif*
# cosicorr_20170501T221601_20200410T221559_NSOffset.tif*
# cosicorr_20170501T221601_20200410T221559_offsetSNR.tif*
# cosicorr_20170804T221559_20180705T221601.dat*
# cosicorr_20170804T221559_20180705T221601.hdr*
# cosicorr_20170804T221559_20180705T221601_EWOffset.tif*
# cosicorr_20170804T221559_20180705T221601_NSOffset.tif*
# cosicorr_20170804T221559_20180705T221601_offsetSNR.tif*
# cosicorr_20170804T221559_20200709T221609.dat*
# cosicorr_20170804T221559_20200709T221609.hdr*
# cosicorr_20170804T221559_20200709T221609_EWOffset.tif*
# cosicorr_20170804T221559_20200709T221609_NSOffset.tif*
# cosicorr_20170804T221559_20200709T221609_offsetSNR.tif*
# cosicorr_20170804T221559_20200803T221611.dat*
# cosicorr_20170804T221559_20200803T221611.hdr*
# cosicorr_20170804T221559_20200803T221611_EWOffset.tif*
# cosicorr_20170804T221559_20200803T221611_NSOffset.tif*
# cosicorr_20170804T221559_20200803T221611_offsetSNR.tif*
# cosicorr_20171013T221549_20181018T221559.dat*
# cosicorr_20171013T221549_20181018T221559.hdr*
# cosicorr_20171013T221549_20181018T221559_EWOffset.tif*
# cosicorr_20171013T221549_20181018T221559_NSOffset.tif*
# cosicorr_20171013T221549_20181018T221559_offsetSNR.tif*
# cosicorr_20171013T221549_20191102T221609.dat*
# cosicorr_20171013T221549_20191102T221609.hdr*
# cosicorr_20171013T221549_20191102T221609_EWOffset.tif*
# cosicorr_20171013T221549_20191102T221609_NSOffset.tif*
# cosicorr_20171013T221549_20191102T221609_offsetSNR.tif*
# cosicorr_20171122T221549_20191102T221609.dat*
# cosicorr_20171122T221549_20191102T221609.hdr*
# cosicorr_20171122T221549_20191102T221609_EWOffset.tif*
# cosicorr_20171122T221549_20191102T221609_NSOffset.tif*
# cosicorr_20171122T221549_20191102T221609_offsetSNR.tif*
# cosicorr_20171122T221549_20191122T221559.dat*
# cosicorr_20171122T221549_20191122T221559.hdr*
# cosicorr_20171122T221549_20191122T221559_EWOffset.tif*
# cosicorr_20171122T221549_20191122T221559_NSOffset.tif*
# cosicorr_20171122T221549_20191122T221559_offsetSNR.tif*
# cosicorr_20171122T221549_20201216T221559.dat*
# cosicorr_20171122T221549_20201216T221559.hdr*
# cosicorr_20171122T221549_20201216T221559_EWOffset.tif*
# cosicorr_20171122T221549_20201216T221559_NSOffset.tif*
# cosicorr_20171122T221549_20201216T221559_offsetSNR.tif*
# cosicorr_20180317T221601_20190302T221601.dat*
# cosicorr_20180317T221601_20190302T221601.hdr*
# cosicorr_20180317T221601_20190302T221601_EWOffset.tif*
# cosicorr_20180317T221601_20190302T221601_NSOffset.tif*
# cosicorr_20180317T221601_20190302T221601_offsetSNR.tif*
# cosicorr_20180317T221601_20200331T221559.dat*
# cosicorr_20180317T221601_20200331T221559.hdr*
# cosicorr_20180317T221601_20200331T221559_EWOffset.tif*
# cosicorr_20180317T221601_20200331T221559_NSOffset.tif*
# cosicorr_20180317T221601_20200331T221559_offsetSNR.tif*
# cosicorr_20180317T221601_20200410T221559.dat*
# cosicorr_20180317T221601_20200410T221559.hdr*
# cosicorr_20180317T221601_20200410T221559_EWOffset.tif*
# cosicorr_20180317T221601_20200410T221559_NSOffset.tif*
# cosicorr_20180317T221601_20200410T221559_offsetSNR.tif*
# cosicorr_20180317T221601_20210219T221601.dat*
# cosicorr_20180317T221601_20210219T221601.hdr*
# cosicorr_20180317T221601_20210219T221601_EWOffset.tif*
# cosicorr_20180317T221601_20210219T221601_NSOffset.tif*
# cosicorr_20180317T221601_20210219T221601_offsetSNR.tif*
# cosicorr_20180317T221601_20210316T221609.dat*
# cosicorr_20180317T221601_20210316T221609.hdr*
# cosicorr_20180317T221601_20210316T221609_EWOffset.tif*
# cosicorr_20180317T221601_20210316T221609_NSOffset.tif*
# cosicorr_20180317T221601_20210316T221609_offsetSNR.tif*
# cosicorr_20180705T221601_20200709T221609.dat*
# cosicorr_20180705T221601_20200709T221609.hdr*
# cosicorr_20180705T221601_20200709T221609_EWOffset.tif*
# cosicorr_20180705T221601_20200709T221609_NSOffset.tif*
# cosicorr_20180705T221601_20200709T221609_offsetSNR.tif*
# cosicorr_20180705T221601_20200803T221611.dat*
# cosicorr_20180705T221601_20200803T221611.hdr*
# cosicorr_20180705T221601_20200803T221611_EWOffset.tif*
# cosicorr_20180705T221601_20200803T221611_NSOffset.tif*
# cosicorr_20180705T221601_20200803T221611_offsetSNR.tif*
# cosicorr_20181018T221559_20191102T221609.dat*
# cosicorr_20181018T221559_20191102T221609.hdr*
# cosicorr_20181018T221559_20191102T221609_EWOffset.tif*
# cosicorr_20181018T221559_20191102T221609_NSOffset.tif*
# cosicorr_20181018T221559_20191102T221609_offsetSNR.tif*
# cosicorr_20190302T221601_20200210T221559.dat*
# cosicorr_20190302T221601_20200210T221559.hdr*
# cosicorr_20190302T221601_20200210T221559_EWOffset.tif*
# cosicorr_20190302T221601_20200210T221559_NSOffset.tif*
# cosicorr_20190302T221601_20200210T221559_offsetSNR.tif*
# cosicorr_20190302T221601_20200331T221559.dat*
# cosicorr_20190302T221601_20200331T221559.hdr*
# cosicorr_20190302T221601_20200331T221559_EWOffset.tif*
# cosicorr_20190302T221601_20200331T221559_NSOffset.tif*
# cosicorr_20190302T221601_20200331T221559_offsetSNR.tif*
# cosicorr_20190302T221601_20210219T221601.dat*
# cosicorr_20190302T221601_20210219T221601.hdr*
# cosicorr_20190302T221601_20210219T221601_EWOffset.tif*
# cosicorr_20190302T221601_20210219T221601_NSOffset.tif*
# cosicorr_20190302T221601_20210219T221601_offsetSNR.tif*
# cosicorr_20190302T221601_20210316T221609.dat*
# cosicorr_20190302T221601_20210316T221609.hdr*
# cosicorr_20190302T221601_20210316T221609_EWOffset.tif*
# cosicorr_20190302T221601_20210316T221609_NSOffset.tif*
# cosicorr_20190302T221601_20210316T221609_offsetSNR.tif*
# cosicorr_20191122T221559_20201216T221559.dat*
# cosicorr_20191122T221559_20201216T221559.hdr*
# cosicorr_20191122T221559_20201216T221559_EWOffset.tif*
# cosicorr_20191122T221559_20201216T221559_NSOffset.tif*
# cosicorr_20191122T221559_20201216T221559_offsetSNR.tif*
# cosicorr_20200210T221559_20210125T221609.dat*
# cosicorr_20200210T221559_20210125T221609.hdr*
# cosicorr_20200210T221559_20210125T221609_EWOffset.tif*
# cosicorr_20200210T221559_20210125T221609_NSOffset.tif*
# cosicorr_20200210T221559_20210125T221609_offsetSNR.tif*
# cosicorr_20200210T221559_20210219T221601.dat*
# cosicorr_20200210T221559_20210219T221601.hdr*
# cosicorr_20200210T221559_20210219T221601_EWOffset.tif*
# cosicorr_20200210T221559_20210219T221601_NSOffset.tif*
# cosicorr_20200210T221559_20210219T221601_offsetSNR.tif*
# cosicorr_20200331T221559_20210316T221609.dat*
# cosicorr_20200331T221559_20210316T221609.hdr*
# cosicorr_20200331T221559_20210316T221609_EWOffset.tif*
# cosicorr_20200331T221559_20210316T221609_NSOffset.tif*
# cosicorr_20200331T221559_20210316T221609_offsetSNR.tif*
# cosicorr_20200410T221559_20210316T221609.dat*
# cosicorr_20200410T221559_20210316T221609.hdr*
# cosicorr_20200410T221559_20210316T221609_EWOffset.tif*
# cosicorr_20200410T221559_20210316T221609_NSOffset.tif*
# cosicorr_20200410T221559_20210316T221609_offsetSNR.tif*
# metadata.txt*

# %% [markdown]
# ## Load Data

# %%
# !load_data.py -t ../pixeloffset_mintpy/cosicorr.cfg
# Out:
# processor : cosicorr
# SAR platform/sensor : unknown from project name "None"
# --------------------------------------------------
# prepare metadata files for cosicorr products
# prep_cosicorr.py /mnt/i/sentinel2/upper/poroa_32/*NSOffset.tif --metadata /mnt/i/sentinel2/upper/poroa_32/metadata.txt
# prep_cosicorr.py /mnt/i/sentinel2/upper/poroa_32/*EWOffset.tif --metadata /mnt/i/sentinel2/upper/poroa_32/metadata.txt
# prep_cosicorr.py /mnt/i/sentinel2/upper/poroa_32/*offsetSNR.tif --metadata /mnt/i/sentinel2/upper/poroa_32/metadata.txt
# --------------------------------------------------
# searching interferometric pairs info
# input data files:
# rangeOffset     : /mnt/i/sentinel2/upper/poroa_32/*EWOffset.tif
# azimuthOffset   : /mnt/i/sentinel2/upper/poroa_32/*NSOffset.tif
# offsetSNR       : /mnt/i/sentinel2/upper/poroa_32/*offsetSNR.tif
# number of rangeOffset     : 37
# number of azimuthOffset   : 37
# number of offsetSNR       : 37
# --------------------------------------------------
# searching geometry files info
# input data files:
# WARNING: No reqired height data files found!
# --------------------------------------------------
# updateMode : False
# compression: None
# x/ystep: 1/1
# create directory: /home/fw/data/poroa_32/inputs
# --------------------------------------------------
# create HDF5 file /home/fw/data/poroa_32/inputs/ifgramStack.h5 with w mode
# create dataset /rangeOffset   of <class 'numpy.float32'>   in size of (37, 301, 226) with compression = None
# [==================================================] 20200410_20210316    4s /     0s
# create dataset /azimuthOffset of <class 'numpy.float32'>   in size of (37, 301, 226) with compression = None
# [==================================================] 20200410_20210316    4s /     0s
# create dataset /offsetSNR     of <class 'numpy.float32'>   in size of (37, 301, 226) with compression = None
# [==================================================] 20200410_20210316    4s /     0s
# create dataset /date          of <class 'numpy.bytes_'>    in size of (37, 2)
# create dataset /bperp         of <class 'numpy.float32'>   in size of (37,)
# create dataset /dropIfgram    of <class 'numpy.bool_'>     in size of (37,)
# Finished writing to /home/fw/data/poroa_32/inputs/ifgramStack.h5
# time used: 00 mins 24.1 secs.

# %% [markdown]
# ## SNR Mask Generation

# %%
# !temporal_average.py inputs/ifgramStack.h5 -d offsetSNR -o avgSNR.h5
# Out:
# output file: avgSNR.h5
# calculate the temporal average of offsetSNR in file inputs/ifgramStack.h5 ...
# [==================================================] lines 301/301    0s /     0s
# create HDF5 file: avgSNR.h5 with w mode
# create dataset /offsetSNR of float32    in size of (301, 226)           with compression=None
# finished writing to avgSNR.h5
# time used: 00 mins 0.1 secs

# %%
data, atr = readfile.read('avgSNR.h5')

fig, ax = plt.subplots(1, 1, tight_layout=True)
ax.hist(data.flatten(),bins=100)
ax.set_xlim(0.8,1)
ax.set_ylim(0.0,50000.0)
# Out:
# (0.0, 50000.0)

# %%
# !generate_mask.py avgSNR.h5 -m 0.8 -o maskSNR.h5
view.main('maskSNR.h5 --noverbose'.split())
# Out:
# input offsetSNR file: avgSNR.h5
# read avgSNR.h5
# create initial mask with the same size as the input file and all = 1
# all pixels with nan value = 0
# exclude pixels with value < 0.8
# create HDF5 file: maskSNR.h5 with w mode
# create dataset /mask of bool       in size of (301, 226)           with compression=None
# finished writing to maskSNR.h5
# time used: 00 mins 0.0 secs.
# view.py maskSNR.h5 --noverbose

# %% [markdown]
# ## Median Removal

# %%
mean_az, date12_list = ut.spatial_average('inputs/ifgramStack.h5', datasetName='azimuthOffset', maskFile='maskSNR.h5', saveList=True)
mean_rg, date12_list = ut.spatial_average('inputs/ifgramStack.h5', datasetName='rangeOffset', maskFile='maskSNR.h5', saveList=True)

az, atr = readfile.read('inputs/ifgramStack.h5', datasetName='azimuthOffset')
rg, atr = readfile.read('inputs/ifgramStack.h5', datasetName='rangeOffset')
snr, atr = readfile.read('inputs/ifgramStack.h5', datasetName='offsetSNR')

for i,m in enumerate(mean_az):
    az[i] -= m

for i,m in enumerate(mean_rg):
    rg[i] -= m

datasetDict = {'rangeOffset':rg, 'azimuthOffset':az, 'offsetSNR':snr}
writefile.write(datasetDict,out_file='inputs/ifgramStack_median.h5',ref_file='inputs/ifgramStack.h5')
# Out:
# calculating spatial mean of azimuthOffset in file inputs/ifgramStack.h5 ...
# read mask from file: maskSNR.h5
# [==================================================] 37/37    0s /     0s
# write average value in space into text file: azimuthOffsetSpatialAvg.txt
# calculating spatial mean of rangeOffset in file inputs/ifgramStack.h5 ...
# read mask from file: maskSNR.h5
# [==================================================] 37/37    0s /     0s
# write average value in space into text file: rangeOffsetSpatialAvg.txt
# create HDF5 file: inputs/ifgramStack_median.h5 with w mode
# create dataset /rangeOffset   of float32    in size of (37, 301, 226)       with compression=None
# create dataset /azimuthOffset of float32    in size of (37, 301, 226)       with compression=None
# create dataset /offsetSNR     of float32    in size of (37, 301, 226)       with compression=None
# create dataset /bperp         of float32    in size of (37,)      with compression=None
# create dataset /date          of |S8        in size of (37, 2)    with compression=None
# create dataset /dropIfgram    of bool       in size of (37,)      with compression=None
# finished writing to inputs/ifgramStack_median.h5
# 'inputs/ifgramStack_median.h5'

# %% [markdown]
# ## Network Selection

# %%
# !spatial_average.py inputs/ifgramStack_median.h5 -d offsetSNR -m maskSNR.h5
cols = ['DATE12','Mean','Btemp/days','Bperp/m','Num']

df = pd.read_csv('offsetSNRSpatialAvg.txt', skiprows=5, sep='	', header=None, names = cols)
df.Mean.plot.hist()
# Out:
# *************** Spatial Average ******************
# calculating spatial median of offsetSNR in file inputs/ifgramStack_median.h5 ...
# read mask from file: maskSNR.h5
# [==================================================] 37/37    0s /     0s
# write average value in space into text file: offsetSNRSpatialAvg.txt
# <AxesSubplot:ylabel='Frequency'>

# %%
limit = 0.9887
exclude = [str(x) for x in df.loc[df['Mean'] < limit, 'Num']]
plt.scatter(df['Btemp/days'],df.Mean)
plt.hlines(limit, 0, df['Btemp/days'].max())

# %%
# !modify_network.py inputs/ifgramStack_median.h5 --reset
# !modify_network.py inputs/ifgramStack_median.h5 --exclude-ifg-index {' '.join(exclude)}
# !modify_network.py -h
# Out:
# No lookup table info range/lat found in files.
# --------------------------------------------------
# reset dataset 'dropIfgram' to True for all interferograms for file: inputs/ifgramStack_median.h5
# All dropIfgram are already True, no need to reset.
# No lookup table info range/lat found in files.
# open ifgramStack file: ifgramStack_median.h5
# number of interferograms: 37
# --------------------------------------------------
# Drop ifgrams with the following index number: 3
# 0 : 20170421_20200331
# 1 : 20170501_20200331
# 2 : 20180317_20200410
# --------------------------------------------------
# number of interferograms to remove: 3
# number of interferograms to keep  : 34
# open file inputs/ifgramStack_median.h5 with r+ mode
# update HDF5 dataset "/dropIfgram".
# update MODIFICATION_TIME in HDF5 dataset "/rangeOffset"
# update MODIFICATION_TIME in HDF5 dataset "/azimuthOffset"
# update MODIFICATION_TIME in HDF5 dataset "/offsetSNR"
# Done.

# %% [markdown]
# ## Inversion

# %%
# !ifgram_inversion.py inputs/ifgramStack_median.h5 -i rangeOffset -w no --md offsetSNR --mt 0.98 -o timeseriesRg.h5 residualInvRg.h5 numInvOffsetRg.h5
# !ifgram_inversion.py inputs/ifgramStack_median.h5 -i azimuthOffset -w no --md offsetSNR --mt 0.98 -o timeseriesAz.h5 residualInvAz.h5 numInvOffsetAz.h5
# !ifgram_inversion.py -h
# Out:
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# skip checking reference pixel info - This is for offset and testing ONLY.
# -------------------------------------------------------------------------------
# least-squares solution with L2 min-norm on: deformation velocity
# minimum redundancy: 1.0
# weight function: no
# mask out pixels with: offsetSNR < 0.98
# ***WARNING: the network is NOT fully connected.
# 	Inversion result can be biased!
# 	Continue to use SVD to resolve the offset between different subsets.
# -------------------------------------------------------------------------------
# number of interferograms: 34
# number of acquisitions  : 22
# number of lines   : 301
# number of columns : 226
# --------------------------------------------------
# create HDF5 file: timeseriesRg.h5 with w mode
# create dataset  : date       of |S8                       in size of (22,)                with compression = None
# create dataset  : bperp      of <class 'numpy.float32'>   in size of (22,)                with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (22, 301, 226)       with compression = None
# close  HDF5 file: timeseriesRg.h5
# --------------------------------------------------
# create HDF5 file: residualInvRg.h5 with w mode
# create dataset  : residual of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# close  HDF5 file: residualInvRg.h5
# --------------------------------------------------
# create HDF5 file: numInvOffsetRg.h5 with w mode
# create dataset  : mask of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# close  HDF5 file: numInvOffsetRg.h5
# maximum memory size: 4.0E+00 GB
# split 301 lines into 2 patches for processing
#     with each patch up to 300 lines
#
# ------- processing patch 1 out of 2 --------------
# box width:  226
# box length: 300
# reading rangeOffset in (0, 0, 226, 300) * 34 ...
# use input reference phase
# reading offsetSNR in (0, 0, 226, 300) * 34 ...
# mask out pixels with offsetSNR < 0.98 by setting them to NaN
# skip pixels with rangeOffset = NaN in all interferograms
# number of pixels to invert: 60060 out of 67800 (88.6%)
# inverting pixels with valid rangeOffset in all  ifgrams (46654 pixels; 77.7%) ...
# inverting pixels with valid rangeOffset in some ifgrams (13406 pixels; 77.7%) ...
# [==================================================] 13406/13406 pixels    2s /     0s
# --------------------------------------------------
# open  HDF5 file timeseriesRg.h5 in a mode
# writing dataset /timeseries                block: [0, 22, 0, 300, 0, 226]
# close HDF5 file timeseriesRg.h5.
# --------------------------------------------------
# open  HDF5 file residualInvRg.h5 in a mode
# writing dataset /residual                  block: [0, 300, 0, 226]
# close HDF5 file residualInvRg.h5.
# --------------------------------------------------
# open  HDF5 file numInvOffsetRg.h5 in a mode
# writing dataset /mask                      block: [0, 300, 0, 226]
# close HDF5 file numInvOffsetRg.h5.
# time used: 00 mins 4.0 secs.
#
#
# ------- processing patch 2 out of 2 --------------
# box width:  226
# box length: 1
# reading rangeOffset in (0, 300, 226, 301) * 34 ...
# use input reference phase
# reading offsetSNR in (0, 300, 226, 301) * 34 ...
# mask out pixels with offsetSNR < 0.98 by setting them to NaN
# skip pixels with rangeOffset = NaN in all interferograms
# number of pixels to invert: 0 out of 226 (0.0%)
# --------------------------------------------------
# open  HDF5 file timeseriesRg.h5 in a mode
# writing dataset /timeseries                block: [0, 22, 300, 301, 0, 226]
# close HDF5 file timeseriesRg.h5.
# --------------------------------------------------
# open  HDF5 file residualInvRg.h5 in a mode
# writing dataset /residual                  block: [300, 301, 0, 226]
# close HDF5 file residualInvRg.h5.
# --------------------------------------------------
# open  HDF5 file numInvOffsetRg.h5 in a mode
# writing dataset /mask                      block: [300, 301, 0, 226]
# close HDF5 file numInvOffsetRg.h5.
# time used: 00 mins 4.1 secs.
#
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 00 mins 4.1 secs.
#
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# skip checking reference pixel info - This is for offset and testing ONLY.
# -------------------------------------------------------------------------------
# least-squares solution with L2 min-norm on: deformation velocity
# minimum redundancy: 1.0
# weight function: no
# mask out pixels with: offsetSNR < 0.98
# ***WARNING: the network is NOT fully connected.
# 	Inversion result can be biased!
# 	Continue to use SVD to resolve the offset between different subsets.
# -------------------------------------------------------------------------------
# number of interferograms: 34
# number of acquisitions  : 22
# number of lines   : 301
# number of columns : 226
# --------------------------------------------------
# create HDF5 file: timeseriesAz.h5 with w mode
# create dataset  : date       of |S8                       in size of (22,)                with compression = None
# create dataset  : bperp      of <class 'numpy.float32'>   in size of (22,)                with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (22, 301, 226)       with compression = None
# close  HDF5 file: timeseriesAz.h5
# --------------------------------------------------
# create HDF5 file: residualInvAz.h5 with w mode
# create dataset  : residual of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# close  HDF5 file: residualInvAz.h5
# --------------------------------------------------
# create HDF5 file: numInvOffsetAz.h5 with w mode
# create dataset  : mask of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# close  HDF5 file: numInvOffsetAz.h5
# maximum memory size: 4.0E+00 GB
# split 301 lines into 2 patches for processing
#     with each patch up to 300 lines
#
# ------- processing patch 1 out of 2 --------------
# box width:  226
# box length: 300
# reading azimuthOffset in (0, 0, 226, 300) * 34 ...
# use input reference phase
# reading offsetSNR in (0, 0, 226, 300) * 34 ...
# mask out pixels with offsetSNR < 0.98 by setting them to NaN
# skip pixels with azimuthOffset = NaN in all interferograms
# number of pixels to invert: 60060 out of 67800 (88.6%)
# inverting pixels with valid azimuthOffset in all  ifgrams (46654 pixels; 77.7%) ...
# inverting pixels with valid azimuthOffset in some ifgrams (13406 pixels; 77.7%) ...
# [==================================================] 13406/13406 pixels    2s /     0s
# --------------------------------------------------
# open  HDF5 file timeseriesAz.h5 in a mode
# writing dataset /timeseries                block: [0, 22, 0, 300, 0, 226]
# close HDF5 file timeseriesAz.h5.
# --------------------------------------------------
# open  HDF5 file residualInvAz.h5 in a mode
# writing dataset /residual                  block: [0, 300, 0, 226]
# close HDF5 file residualInvAz.h5.
# --------------------------------------------------
# open  HDF5 file numInvOffsetAz.h5 in a mode
# writing dataset /mask                      block: [0, 300, 0, 226]
# close HDF5 file numInvOffsetAz.h5.
# time used: 00 mins 4.0 secs.
#
#
# ------- processing patch 2 out of 2 --------------
# box width:  226
# box length: 1
# reading azimuthOffset in (0, 300, 226, 301) * 34 ...
# use input reference phase
# reading offsetSNR in (0, 300, 226, 301) * 34 ...
# mask out pixels with offsetSNR < 0.98 by setting them to NaN
# skip pixels with azimuthOffset = NaN in all interferograms
# number of pixels to invert: 0 out of 226 (0.0%)
# --------------------------------------------------
# open  HDF5 file timeseriesAz.h5 in a mode
# writing dataset /timeseries                block: [0, 22, 300, 301, 0, 226]
# close HDF5 file timeseriesAz.h5.
# --------------------------------------------------
# open  HDF5 file residualInvAz.h5 in a mode
# writing dataset /residual                  block: [300, 301, 0, 226]
# close HDF5 file residualInvAz.h5.
# --------------------------------------------------
# open  HDF5 file numInvOffsetAz.h5 in a mode
# writing dataset /mask                      block: [300, 301, 0, 226]
# close HDF5 file numInvOffsetAz.h5.
# time used: 00 mins 4.0 secs.
#
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 00 mins 4.0 secs.

# %% [markdown]
# ## timeseries2velocity

# %%
# !timeseries2velocity.py timeseriesAz.h5 --bootstrap -o velocityAz.h5
# !timeseries2velocity.py timeseriesRg.h5 --bootstrap -o velocityRg.h5
# Out:
# bootstrapping is turned ON.
# open timeseries file: timeseriesAz.h5
# --------------------------------------------------
# dates from input file: 22
# ['20160206', '20161122', '20170421', '20170501', '20170804', '20171013', '20171122', '20180317', '20180705', '20181018', '20190302', '20191102', '20191122', '20200210', '20200331', '20200410', '20200709', '20200803', '20201216', '20210125', '20210219', '20210316']
# --------------------------------------------------
# using all dates to calculate the velocity
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     step       : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'bootstrap', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: velocityAz.h5 with w mode
# create dataset  : velocity    of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# create dataset  : velocityStd of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# add /velocity    attribute: UNIT = m/year
# add /velocityStd attribute: UNIT = m/year
# close  HDF5 file: velocityAz.h5
# reading data from file timeseriesAz.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 58316 out of 68026 (85.7%)
# estimating time functions via linalg.lstsq ...
# estimating time function STD with bootstrap resampling (400 times) ...
# [==================================================] iteration 400 / 400   14s /     0s
# --------------------------------------------------
# open  HDF5 file velocityAz.h5 in a mode
# writing dataset /velocity                  block: [0, 301, 0, 226]
# close HDF5 file velocityAz.h5.
# --------------------------------------------------
# open  HDF5 file velocityAz.h5 in a mode
# writing dataset /velocityStd               block: [0, 301, 0, 226]
# close HDF5 file velocityAz.h5.
# time used: 00 mins 15.1 secs.
# bootstrapping is turned ON.
# open timeseries file: timeseriesRg.h5
# --------------------------------------------------
# dates from input file: 22
# ['20160206', '20161122', '20170421', '20170501', '20170804', '20171013', '20171122', '20180317', '20180705', '20181018', '20190302', '20191102', '20191122', '20200210', '20200331', '20200410', '20200709', '20200803', '20201216', '20210125', '20210219', '20210316']
# --------------------------------------------------
# using all dates to calculate the velocity
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     step       : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'bootstrap', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: velocityRg.h5 with w mode
# create dataset  : velocity    of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# create dataset  : velocityStd of <class 'numpy.float32'>   in size of (301, 226)           with compression = None
# add /velocity    attribute: UNIT = m/year
# add /velocityStd attribute: UNIT = m/year
# close  HDF5 file: velocityRg.h5
# reading data from file timeseriesRg.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 58316 out of 68026 (85.7%)
# estimating time functions via linalg.lstsq ...
# estimating time function STD with bootstrap resampling (400 times) ...
# [==================================================] iteration 400 / 400   14s /     0s
# --------------------------------------------------
# open  HDF5 file velocityRg.h5 in a mode
# writing dataset /velocity                  block: [0, 301, 0, 226]
# close HDF5 file velocityRg.h5.
# --------------------------------------------------
# open  HDF5 file velocityRg.h5 in a mode
# writing dataset /velocityStd               block: [0, 301, 0, 226]
# close HDF5 file velocityRg.h5.
# time used: 00 mins 15.3 secs.

# %%
view.main('velocityAz.h5 --noverbose'.split())
# Out:
# view.py velocityAz.h5 --noverbose

# %%
view.main('velocityRg.h5 --noverbose'.split())
# Out:
# view.py velocityRg.h5 --noverbose

# %% [markdown]
# ## To GeoTIFF

# %%
#need to change line to 32760
# !save_gdal.py velocityAz.h5 -o velocityAz.tif
# !save_gdal.py velocityRg.h5 -o velocityRg.tif
# Out:
# read metadata from file: velocityAz.h5
# read data     from file: velocityAz.h5
# initiate GDAL driver: GeoTIFF
# create raster band
# raster row / column number: 301, 226
# raster transform info: (398700.0, 40.0, 0, 5604370.0, 0, -40.0)
# write data to raster band
# set projectection as: EPSG 4326
# finished writing to /home/fw/data/upper_poroa/velocityAz.tif
# read metadata from file: velocityRg.h5
# read data     from file: velocityRg.h5
# initiate GDAL driver: GeoTIFF
# create raster band
# raster row / column number: 301, 226
# raster transform info: (398700.0, 40.0, 0, 5604370.0, 0, -40.0)
# write data to raster band
# set projectection as: EPSG 4326
# finished writing to /home/fw/data/upper_poroa/velocityRg.tif

# %% [markdown]
# ## Move

# %%
# !cp velocityAz.tif /mnt/i/sentinel2/upper/velocityAz.tif
# !cp velocityRg.tif /mnt/i/sentinel2/upper/velocityRg.tif

# %% [markdown]
# ## Viewing

# %%
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
# view.main('median/velocityAz.h5 --noverbose'.split())

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# !info.py inputs/ifgramStack.h5
# help(readfile.read)
s = slice(200,250), slice(200,250)
fname = '../cosicorr_20161122T221602_20190225T221559_EWOffset.tif'

# mintpy_data = readfile.read_gdal(fname)

mintpy_data, atr = readfile.read('inputs/ifgramStack.h5', datasetName='rangeOffset-20161122_20190225')

ds = gdal.Open(fname)
gdal_data = ds.GetRasterBand(1).ReadAsArray()
ds = None

matches = gdal_data - mintpy_data
print(np.unique(matches))
fig, ax = plt.subplots()
# im = ax.imshow(gdal_data[s])
# im = ax.imshow(mintpy_data[s])
im = ax.imshow(matches[s])
ax.figure.colorbar(im)
# Out:
# [ 0. nan]

# %%
# !ifgram_inversion.py inputs/ifgramStack.h5 -i rangeOffset -w no --md offsetSNR --mt 5
# ifgram_inversion.py inputs/ifgramStack.h5 -i azimuthOffset -w no -m waterMask.h5 --md offsetSNR --mt 5
# Out:
# skip checking reference pixel info - This is for offset and testing ONLY.
# -------------------------------------------------------------------------------
# least-squares solution with L2 min-norm on: deformation velocity
# minimum redundancy: 1.0
# weight function: no
# mask out pixels with: offsetSNR < 5.0
# -------------------------------------------------------------------------------
# number of interferograms: 15
# number of acquisitions  : 6
# number of lines   : 501
# number of columns : 501
# --------------------------------------------------
# create HDF5 file: timeseriesRg.h5 with w mode
# create dataset  : date       of |S8                       in size of (6,)                 with compression = None
# create dataset  : bperp      of <class 'numpy.float32'>   in size of (6,)                 with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (6, 501, 501)        with compression = None
# close  HDF5 file: timeseriesRg.h5
# --------------------------------------------------
# create HDF5 file: residualInvRg.h5 with w mode
# create dataset  : residual of <class 'numpy.float32'>   in size of (501, 501)           with compression = None
# close  HDF5 file: residualInvRg.h5
# --------------------------------------------------
# create HDF5 file: numInvOffset.h5 with w mode
# create dataset  : mask of <class 'numpy.float32'>   in size of (501, 501)           with compression = None
# close  HDF5 file: numInvOffset.h5
# maximum memory size: 4.0E+00 GB
# split 501 lines into 2 patches for processing
#     with each patch up to 500 lines
#
# ------- processing patch 1 out of 2 --------------
# box width:  501
# box length: 500
# reading rangeOffset in (0, 0, 501, 500) * 15 ...
# use input reference phase
# reading offsetSNR in (0, 0, 501, 500) * 15 ...
# mask out pixels with offsetSNR < 5.0 by setting them to NaN
# skip pixels with rangeOffset = NaN in all interferograms
# number of pixels to invert: 231739 out of 250500 (92.5%)
# inverting pixels with valid rangeOffset in all  ifgrams (72 pixels; 0.0%) ...
# /home/fw/miniconda3/envs/mintpy_clean/lib/python3.8/site-packages/scipy/linalg/basic.py:1220: RuntimeWarning: overflow encountered in square
#   resids = np.sum(np.abs(x[n:])**2, axis=0)
# /home/fw/miniconda3/envs/mintpy_clean/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# inverting pixels with valid rangeOffset in some ifgrams (231667 pixels; 0.0%) ...
# [======>                 14%                       ] 32000/231667 pixels    1s /    11s/home/fw/tools/MintPy/mintpy/ifgram_inversion.py:405: RuntimeWarning: overflow encountered in multiply
#   ts_diff = X * np.tile(tbase_diff, (1, num_pixel))
# [==================================================] 231667/231667 pixels   13s /     0s
# Traceback (most recent call last):
#   File "/home/fw/tools/MintPy/mintpy/ifgram_inversion.py", line 1207, in <module>
#     main(sys.argv[1:])
#   File "/home/fw/tools/MintPy/mintpy/ifgram_inversion.py", line 1196, in main
#     ifgram_inversion(inps)
#   File "/home/fw/tools/MintPy/mintpy/ifgram_inversion.py", line 1113, in ifgram_inversion
#     ts, inv_quality, num_inv_ifg = ifgram_inversion_patch(**data_kwargs)[:-1]
#   File "/home/fw/tools/MintPy/mintpy/ifgram_inversion.py", line 973, in ifgram_inversion_patch
#     rg_pixel_size = float(stack_obj.metadata['RANGE_PIXEL_SIZE'])
# KeyError: 'RANGE_PIXEL_SIZE'

# %% [markdown]
# ## Double Difference

# %%
# !spatial_filter.py inputs/ifgramStack.h5 azimuthOffset rangeOffset -o inputs/ifgramStackDD.h5  -f double_difference -p 1 12
# Out:
# filtering ifgramStack file: inputs/ifgramStack.h5 using double_difference filter with local/regional kernel sizes of 1/12
# filtering azimuthOffset from ifgramStack.h5  15/15 ...
# filtering rangeOffset   from ifgramStack.h5  15/15 ...
# create HDF5 file: inputs/ifgramStackDD.h5 with w mode
# create dataset /offsetSNR     of float32    in size of (15, 501, 501)       with compression=None
# create dataset /azimuthOffset of float32    in size of (15, 501, 501)       with compression=None
# create dataset /rangeOffset   of float32    in size of (15, 501, 501)       with compression=None
# create dataset /bperp         of float32    in size of (15,)      with compression=None
# create dataset /date          of |S8        in size of (15, 2)    with compression=None
# create dataset /dropIfgram    of bool       in size of (15,)      with compression=None
# finished writing to inputs/ifgramStackDD.h5
# Done.

# %% [markdown]
# ## Spatial Average

# %%
# !spatial_filter.py inputs/ifgramStack.h5 azimuthOffset rangeOffset -o inputs/ifgramStackLocal.h5 -f lowpass_avg -p 12
# Out:
# filtering ifgramStack file: inputs/ifgramStack.h5 using lowpass_avg filter with kernel size of 12
# filtering azimuthOffset from ifgramStack.h5  15/15 ...
# filtering rangeOffset   from ifgramStack.h5  15/15 ...
# create HDF5 file: inputs/ifgramStackLocal.h5 with w mode
# create dataset /offsetSNR     of float32    in size of (15, 501, 501)       with compression=None
# create dataset /azimuthOffset of float32    in size of (15, 501, 501)       with compression=None
# create dataset /rangeOffset   of float32    in size of (15, 501, 501)       with compression=None
# create dataset /bperp         of float32    in size of (15,)      with compression=None
# create dataset /date          of |S8        in size of (15, 2)    with compression=None
# create dataset /dropIfgram    of bool       in size of (15,)      with compression=None
# finished writing to inputs/ifgramStackLocal.h5
# Done.
